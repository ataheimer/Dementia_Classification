# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

def apply_augmentation(image, method_index):
    if method_index == 0:
        # Rastgele döndürme
        angle = np.random.uniform(-30, 30)
        augmented_image = rotate_image(image, angle)
    elif method_index == 1:
        # Yatay ve dikey kaydırma
        height, width = image.shape[:2]
        tx = np.random.uniform(-0.05 * width, 0.05 * width)
        ty = np.random.uniform(-0.05 * height, 0.05 * height)
        augmented_image = shift_image(image, tx, ty)
    elif method_index == 2:
        # Parlaklık değişikliği
        brightness = np.random.uniform(0.2, 0.8)
        augmented_image = apply_brightness(image, brightness)
    elif method_index == 3:
        # Yakınlaştırma
        zoom = np.random.uniform(0.8, 1.2)
        augmented_image = zoom_image(image, zoom)
    elif method_index == 4:
        # Kanal kaydırma
        channel_shift_intensity = np.random.uniform(-0.2, 0.2)
        augmented_image = channel_shift(image, channel_shift_intensity)
    elif method_index == 5:
        # Gürültü ekleme
        noise_intensity = np.random.uniform(0, 0.1)
        augmented_image = add_noise(image, noise_intensity)
    elif method_index == 6:
        # Yatay çevirme
        augmented_image = flip_image(image, horizontal=True)
    elif method_index == 7:
        # Dikey çevirme
        augmented_image = flip_image(image, horizontal=False)
    else:
        augmented_image = image  # Varsayılan olarak orijinal resim
    
    return augmented_image

def rotate_image(image, angle):
    height, width = image.shape[:2]
    rotation_matrix = cv2.getRotationMatrix2D((width / 2, height / 2), angle, 1)
    rotated_image = cv2.warpAffine(image, rotation_matrix, (width, height))
    return rotated_image

def shift_image(image, dx, dy):
    height, width = image.shape[:2]
    translation_matrix = np.float32([[1, 0, dx], [0, 1, dy]])
    shifted_image = cv2.warpAffine(image, translation_matrix, (width, height))
    return shifted_image

def apply_brightness(image, brightness):
    image = image * brightness
    return np.clip(image, 0, 1)

def zoom_image(image, zoom):
    height, width = image.shape[:2]
    zoom_matrix = cv2.resize(image, None, fx=zoom, fy=zoom)
    zoom_height, zoom_width = zoom_matrix.shape[:2]

    start_x = max(zoom_width // 2 - width // 2, 0)
    start_y = max(zoom_height // 2 - height // 2, 0)
    end_x = start_x + width
    end_y = start_y + height

    zoom_image = zoom_matrix[start_y:end_y, start_x:end_x]
    return zoom_image

def channel_shift(image, intensity):
    image = image + intensity * np.std(image)
    return np.clip(image, 0, 1)

def add_noise(image, noise_intensity):
    noise = np.random.normal(0, noise_intensity, image.shape)
    noisy_image = image + noise
    return np.clip(noisy_image, 0, 1)

def flip_image(image, horizontal=True):
    if horizontal:
        return cv2.flip(image, 1)  # Yatay çevirme
    else:
        return cv2.flip(image, 0)  # Dikey çevirme

def augment_images_in_folder(input_folder, output_folder):
    # Giriş ve çıkış klasörlerinin mevcut olup olmadığını kontrol et
    if not os.path.exists(input_folder):
        raise FileNotFoundError(f"Giriş klasörü bulunamadı: {input_folder}")
    
    os.makedirs(output_folder, exist_ok=True)

    # Klasördeki tüm resim dosyalarını listeleme
    image_files = [f for f in os.listdir(input_folder) if os.path.isfile(os.path.join(input_folder, f))]

    for image_file in image_files:
        image_path = os.path.join(input_folder, image_file)
        mr_image = cv2.imread(image_path)

        # Görüntünün doğru yüklendiğinden emin olun
        if mr_image is None:
            print(f"Görüntü yüklenemedi: {image_path}")
            continue

        # Görüntüyü yeniden boyutlandır
        mr_image_resized = cv2.resize(mr_image, (128, 128))

        # Görüntüyü gri tonlamalı hale getirin (gerekiyorsa)
        if len(mr_image_resized.shape) == 3 and mr_image_resized.shape[2] == 3:
            mr_image_gray = cv2.cvtColor(mr_image_resized, cv2.COLOR_BGR2GRAY)
        else:
            mr_image_gray = mr_image_resized

        # Görüntüyü normalizasyon işlemi (0-1 aralığına getirme)
        mr_image_normalized = mr_image_gray / 255.0

        # dokuz farklı arttırılmış resim oluşturalım ve kaydedelim
        augmented_images = []
        for i in range(9):
            augmented_image = apply_augmentation(mr_image_normalized, i)
            augmented_images.append(augmented_image)
            
            # Görüntüyü 0-255 aralığına geri döndür ve uint8 formatına dönüştür
            augmented_image_uint8 = (augmented_image * 255).astype(np.uint8)
            
            # Kaydet
            output_path = os.path.join(output_folder, f'{os.path.splitext(image_file)[0]}_augmented_{i+1}.png')
            cv2.imwrite(output_path, augmented_image_uint8)
        print(f"İşlenen görüntüler kaydedildi: {image_file}")

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

def apply_augmentation2(image, method_index):
    if method_index == 0:
        # Rastgele döndürme
        angle = np.random.uniform(-30, 30)
        augmented_image = rotate_image(image, angle)
    elif method_index == 1:
        # Yatay ve dikey kaydırma
        height, width = image.shape[:2]
        tx = np.random.uniform(-0.05 * width, 0.05 * width)
        ty = np.random.uniform(-0.05 * height, 0.05 * height)
        augmented_image = shift_image(image, tx, ty)
    elif method_index == 2:
        # Yatay çevirme
        augmented_image = flip_image(image, horizontal=True)
    elif method_index == 3:
        # Dikey çevirme
        augmented_image = flip_image(image, horizontal=False)
    else:
        augmented_image = image  # Varsayılan olarak orijinal resim
    
    return augmented_image

def rotate_image(image, angle):
    height, width = image.shape[:2]
    rotation_matrix = cv2.getRotationMatrix2D((width / 2, height / 2), angle, 1)
    rotated_image = cv2.warpAffine(image, rotation_matrix, (width, height))
    return rotated_image

def shift_image(image, dx, dy):
    height, width = image.shape[:2]
    translation_matrix = np.float32([[1, 0, dx], [0, 1, dy]])
    shifted_image = cv2.warpAffine(image, translation_matrix, (width, height))
    return shifted_image

def flip_image(image, horizontal=True):
    if horizontal:
        return cv2.flip(image, 1)  # Yatay çevirme
    else:
        return cv2.flip(image, 0)  # Dikey çevirme

def augment_images_in_folder2(input_folder, output_folder):
    # Giriş ve çıkış klasörlerinin mevcut olup olmadığını kontrol et
    if not os.path.exists(input_folder):
        raise FileNotFoundError(f"Giriş klasörü bulunamadı: {input_folder}")
    
    os.makedirs(output_folder, exist_ok=True)

    # Klasördeki tüm resim dosyalarını listeleme
    image_files = [f for f in os.listdir(input_folder) if os.path.isfile(os.path.join(input_folder, f))]

    for image_file in image_files:
        image_path = os.path.join(input_folder, image_file)
        mr_image = cv2.imread(image_path)

        # Görüntünün doğru yüklendiğinden emin olun
        if mr_image is None:
            print(f"Görüntü yüklenemedi: {image_path}")
            continue

        # Görüntüyü yeniden boyutlandır
        mr_image_resized = cv2.resize(mr_image, (128, 128))

        # Görüntüyü gri tonlamalı hale getirin (gerekiyorsa)
        if len(mr_image_resized.shape) == 3 and mr_image_resized.shape[2] == 3:
            mr_image_gray = cv2.cvtColor(mr_image_resized, cv2.COLOR_BGR2GRAY)
        else:
            mr_image_gray = mr_image_resized

        # Görüntüyü normalizasyon işlemi (0-1 aralığına getirme)
        mr_image_normalized = mr_image_gray / 255.0

        # dokuz farklı arttırılmış resim oluşturalım ve kaydedelim
        augmented_images = []
        for i in range(2):
            augmented_image = apply_augmentation2(mr_image_normalized, i)
            augmented_images.append(augmented_image)
            
            # Görüntüyü 0-255 aralığına geri döndür ve uint8 formatına dönüştür
            augmented_image_uint8 = (augmented_image * 255).astype(np.uint8)
            
            # Kaydet
            output_path = os.path.join(output_folder, f'{os.path.splitext(image_file)[0]}_augmented_{i+1}.png')
            cv2.imwrite(output_path, augmented_image_uint8)
        print(f"İşlenen görüntüler kaydedildi: {image_file}")

# %%
input_folder = 'Output_filtered/processed/2' # Giriş klasörü yolu
output_folder = 'Output_filtered/processed2/label_2'  # Çıkış klasörü yolu
augment_images_in_folder2(input_folder, output_folder)
# Out:
# İşlenen görüntüler kaydedildi: 2_processed_1.png
# İşlenen görüntüler kaydedildi: 2_processed_10.png
# İşlenen görüntüler kaydedildi: 2_processed_100.png
# İşlenen görüntüler kaydedildi: 2_processed_1000.png
# İşlenen görüntüler kaydedildi: 2_processed_1001.png
# İşlenen görüntüler kaydedildi: 2_processed_1002.png
# İşlenen görüntüler kaydedildi: 2_processed_1003.png
# İşlenen görüntüler kaydedildi: 2_processed_1004.png
# İşlenen görüntüler kaydedildi: 2_processed_1005.png
# İşlenen görüntüler kaydedildi: 2_processed_1006.png
# İşlenen görüntüler kaydedildi: 2_processed_1007.png
# İşlenen görüntüler kaydedildi: 2_processed_1008.png
# İşlenen görüntüler kaydedildi: 2_processed_1009.png
# İşlenen görüntüler kaydedildi: 2_processed_101.png
# İşlenen görüntüler kaydedildi: 2_processed_1010.png
# İşlenen görüntüler kaydedildi: 2_processed_1011.png
# İşlenen görüntüler kaydedildi: 2_processed_1012.png
# İşlenen görüntüler kaydedildi: 2_processed_1013.png
# İşlenen görüntüler kaydedildi: 2_processed_1014.png
# İşlenen görüntüler kaydedildi: 2_processed_1015.png
# İşlenen görüntüler kaydedildi: 2_processed_1016.png
# İşlenen görüntüler kaydedildi: 2_processed_1017.png
# İşlenen görüntüler kaydedildi: 2_processed_1018.png
# İşlenen görüntüler kaydedildi: 2_processed_1019.png
# İşlenen görüntüler kaydedildi: 2_processed_102.png
# İşlenen görüntüler kaydedildi: 2_processed_1020.png
# İşlenen görüntüler kaydedildi: 2_processed_1021.png
# İşlenen görüntüler kaydedildi: 2_processed_1022.png
# İşlenen görüntüler kaydedildi: 2_processed_1023.png
# İşlenen görüntüler kaydedildi: 2_processed_1024.png
# İşlenen görüntüler kaydedildi: 2_processed_1025.png
# İşlenen görüntüler kaydedildi: 2_processed_1026.png
# İşlenen görüntüler kaydedildi: 2_processed_1027.png
# İşlenen görüntüler kaydedildi: 2_processed_1028.png
# İşlenen görüntüler kaydedildi: 2_processed_1029.png
# İşlenen görüntüler kaydedildi: 2_processed_103.png
# İşlenen görüntüler kaydedildi: 2_processed_1030.png
# İşlenen görüntüler kaydedildi: 2_processed_1031.png
# İşlenen görüntüler kaydedildi: 2_processed_1032.png
# İşlenen görüntüler kaydedildi: 2_processed_1033.png
# İşlenen görüntüler kaydedildi: 2_processed_1034.png
# İşlenen görüntüler kaydedildi: 2_processed_1035.png
# İşlenen görüntüler kaydedildi: 2_processed_1036.png
# İşlenen görüntüler kaydedildi: 2_processed_1037.png
# İşlenen görüntüler kaydedildi: 2_processed_1038.png
# İşlenen görüntüler kaydedildi: 2_processed_1039.png
# İşlenen görüntüler kaydedildi: 2_processed_104.png
# İşlenen görüntüler kaydedildi: 2_processed_1040.png
# İşlenen görüntüler kaydedildi: 2_processed_1041.png
# İşlenen görüntüler kaydedildi: 2_processed_1042.png
# İşlenen görüntüler kaydedildi: 2_processed_1043.png
# İşlenen görüntüler kaydedildi: 2_processed_1044.png
# İşlenen görüntüler kaydedildi: 2_processed_1045.png
# İşlenen görüntüler kaydedildi: 2_processed_1046.png
# İşlenen görüntüler kaydedildi: 2_processed_1047.png
# İşlenen görüntüler kaydedildi: 2_processed_1048.png
# İşlenen görüntüler kaydedildi: 2_processed_1049.png
# İşlenen görüntüler kaydedildi: 2_processed_105.png
# İşlenen görüntüler kaydedildi: 2_processed_1050.png
# İşlenen görüntüler kaydedildi: 2_processed_1051.png
# İşlenen görüntüler kaydedildi: 2_processed_1052.png
# İşlenen görüntüler kaydedildi: 2_processed_1053.png
# İşlenen görüntüler kaydedildi: 2_processed_1054.png
# İşlenen görüntüler kaydedildi: 2_processed_1055.png
# İşlenen görüntüler kaydedildi: 2_processed_1056.png
# İşlenen görüntüler kaydedildi: 2_processed_1057.png
# İşlenen görüntüler kaydedildi: 2_processed_1058.png
# İşlenen görüntüler kaydedildi: 2_processed_1059.png
# İşlenen görüntüler kaydedildi: 2_processed_106.png
# İşlenen görüntüler kaydedildi: 2_processed_1060.png
# İşlenen görüntüler kaydedildi: 2_processed_1061.png
# İşlenen görüntüler kaydedildi: 2_processed_1062.png
# İşlenen görüntüler kaydedildi: 2_processed_1063.png
# İşlenen görüntüler kaydedildi: 2_processed_1064.png
# İşlenen görüntüler kaydedildi: 2_processed_1065.png
# İşlenen görüntüler kaydedildi: 2_processed_1066.png
# İşlenen görüntüler kaydedildi: 2_processed_1067.png
# İşlenen görüntüler kaydedildi: 2_processed_1068.png
# İşlenen görüntüler kaydedildi: 2_processed_1069.png
# İşlenen görüntüler kaydedildi: 2_processed_107.png
# İşlenen görüntüler kaydedildi: 2_processed_1070.png
# İşlenen görüntüler kaydedildi: 2_processed_1071.png
# İşlenen görüntüler kaydedildi: 2_processed_1072.png
# İşlenen görüntüler kaydedildi: 2_processed_1073.png
# İşlenen görüntüler kaydedildi: 2_processed_1074.png
# İşlenen görüntüler kaydedildi: 2_processed_1075.png
# İşlenen görüntüler kaydedildi: 2_processed_1076.png
# İşlenen görüntüler kaydedildi: 2_processed_1077.png
# İşlenen görüntüler kaydedildi: 2_processed_1078.png
# İşlenen görüntüler kaydedildi: 2_processed_1079.png
# İşlenen görüntüler kaydedildi: 2_processed_108.png
# İşlenen görüntüler kaydedildi: 2_processed_1080.png
# İşlenen görüntüler kaydedildi: 2_processed_1081.png
# İşlenen görüntüler kaydedildi: 2_processed_1082.png
# İşlenen görüntüler kaydedildi: 2_processed_1083.png
# İşlenen görüntüler kaydedildi: 2_processed_1084.png
# İşlenen görüntüler kaydedildi: 2_processed_1085.png
# İşlenen görüntüler kaydedildi: 2_processed_1086.png
# İşlenen görüntüler kaydedildi: 2_processed_1087.png
# İşlenen görüntüler kaydedildi: 2_processed_1088.png
# İşlenen görüntüler kaydedildi: 2_processed_1089.png
# İşlenen görüntüler kaydedildi: 2_processed_109.png
# İşlenen görüntüler kaydedildi: 2_processed_1090.png
# İşlenen görüntüler kaydedildi: 2_processed_1091.png
# İşlenen görüntüler kaydedildi: 2_processed_1092.png
# İşlenen görüntüler kaydedildi: 2_processed_1093.png
# İşlenen görüntüler kaydedildi: 2_processed_1094.png
# İşlenen görüntüler kaydedildi: 2_processed_1095.png
# İşlenen görüntüler kaydedildi: 2_processed_1096.png
# İşlenen görüntüler kaydedildi: 2_processed_1097.png
# İşlenen görüntüler kaydedildi: 2_processed_1098.png
# İşlenen görüntüler kaydedildi: 2_processed_1099.png
# İşlenen görüntüler kaydedildi: 2_processed_11.png
# İşlenen görüntüler kaydedildi: 2_processed_110.png
# İşlenen görüntüler kaydedildi: 2_processed_1100.png
# İşlenen görüntüler kaydedildi: 2_processed_1101.png
# İşlenen görüntüler kaydedildi: 2_processed_1102.png
# İşlenen görüntüler kaydedildi: 2_processed_1103.png
# İşlenen görüntüler kaydedildi: 2_processed_1104.png
# İşlenen görüntüler kaydedildi: 2_processed_1105.png
# İşlenen görüntüler kaydedildi: 2_processed_1106.png
# İşlenen görüntüler kaydedildi: 2_processed_1107.png
# İşlenen görüntüler kaydedildi: 2_processed_1108.png
# İşlenen görüntüler kaydedildi: 2_processed_1109.png
# İşlenen görüntüler kaydedildi: 2_processed_111.png
# İşlenen görüntüler kaydedildi: 2_processed_1110.png
# İşlenen görüntüler kaydedildi: 2_processed_1111.png
# İşlenen görüntüler kaydedildi: 2_processed_1112.png
# İşlenen görüntüler kaydedildi: 2_processed_1113.png
# İşlenen görüntüler kaydedildi: 2_processed_1114.png
# İşlenen görüntüler kaydedildi: 2_processed_1115.png
# İşlenen görüntüler kaydedildi: 2_processed_1116.png
# İşlenen görüntüler kaydedildi: 2_processed_1117.png
# İşlenen görüntüler kaydedildi: 2_processed_1118.png
# İşlenen görüntüler kaydedildi: 2_processed_1119.png
# İşlenen görüntüler kaydedildi: 2_processed_112.png
# İşlenen görüntüler kaydedildi: 2_processed_1120.png
# İşlenen görüntüler kaydedildi: 2_processed_1121.png
# İşlenen görüntüler kaydedildi: 2_processed_1122.png
# İşlenen görüntüler kaydedildi: 2_processed_1123.png
# İşlenen görüntüler kaydedildi: 2_processed_1124.png
# İşlenen görüntüler kaydedildi: 2_processed_1125.png
# İşlenen görüntüler kaydedildi: 2_processed_1126.png
# İşlenen görüntüler kaydedildi: 2_processed_1127.png
# İşlenen görüntüler kaydedildi: 2_processed_1128.png
# İşlenen görüntüler kaydedildi: 2_processed_1129.png
# İşlenen görüntüler kaydedildi: 2_processed_113.png
# İşlenen görüntüler kaydedildi: 2_processed_1130.png
# İşlenen görüntüler kaydedildi: 2_processed_1131.png
# İşlenen görüntüler kaydedildi: 2_processed_1132.png
# İşlenen görüntüler kaydedildi: 2_processed_1133.png
# İşlenen görüntüler kaydedildi: 2_processed_1134.png
# İşlenen görüntüler kaydedildi: 2_processed_1135.png
# İşlenen görüntüler kaydedildi: 2_processed_1136.png
# İşlenen görüntüler kaydedildi: 2_processed_1137.png
# İşlenen görüntüler kaydedildi: 2_processed_1138.png
# İşlenen görüntüler kaydedildi: 2_processed_1139.png
# İşlenen görüntüler kaydedildi: 2_processed_114.png
# İşlenen görüntüler kaydedildi: 2_processed_1140.png
# İşlenen görüntüler kaydedildi: 2_processed_1141.png
# İşlenen görüntüler kaydedildi: 2_processed_1142.png
# İşlenen görüntüler kaydedildi: 2_processed_1143.png
# İşlenen görüntüler kaydedildi: 2_processed_1144.png
# İşlenen görüntüler kaydedildi: 2_processed_1145.png
# İşlenen görüntüler kaydedildi: 2_processed_1146.png
# İşlenen görüntüler kaydedildi: 2_processed_1147.png
# İşlenen görüntüler kaydedildi: 2_processed_1148.png
# İşlenen görüntüler kaydedildi: 2_processed_1149.png
# İşlenen görüntüler kaydedildi: 2_processed_115.png
# İşlenen görüntüler kaydedildi: 2_processed_1150.png
# İşlenen görüntüler kaydedildi: 2_processed_1151.png
# İşlenen görüntüler kaydedildi: 2_processed_1152.png
# İşlenen görüntüler kaydedildi: 2_processed_1153.png
# İşlenen görüntüler kaydedildi: 2_processed_1154.png
# İşlenen görüntüler kaydedildi: 2_processed_1155.png
# İşlenen görüntüler kaydedildi: 2_processed_1156.png
# İşlenen görüntüler kaydedildi: 2_processed_1157.png
# İşlenen görüntüler kaydedildi: 2_processed_1158.png
# İşlenen görüntüler kaydedildi: 2_processed_1159.png
# İşlenen görüntüler kaydedildi: 2_processed_116.png
# İşlenen görüntüler kaydedildi: 2_processed_1160.png
# İşlenen görüntüler kaydedildi: 2_processed_1161.png
# İşlenen görüntüler kaydedildi: 2_processed_1162.png
# İşlenen görüntüler kaydedildi: 2_processed_1163.png
# İşlenen görüntüler kaydedildi: 2_processed_1164.png
# İşlenen görüntüler kaydedildi: 2_processed_1165.png
# İşlenen görüntüler kaydedildi: 2_processed_1166.png
# İşlenen görüntüler kaydedildi: 2_processed_1167.png
# İşlenen görüntüler kaydedildi: 2_processed_1168.png
# İşlenen görüntüler kaydedildi: 2_processed_1169.png
# İşlenen görüntüler kaydedildi: 2_processed_117.png
# İşlenen görüntüler kaydedildi: 2_processed_1170.png
# İşlenen görüntüler kaydedildi: 2_processed_1171.png
# İşlenen görüntüler kaydedildi: 2_processed_1172.png
# İşlenen görüntüler kaydedildi: 2_processed_1173.png
# İşlenen görüntüler kaydedildi: 2_processed_1174.png
# İşlenen görüntüler kaydedildi: 2_processed_1175.png
# İşlenen görüntüler kaydedildi: 2_processed_1176.png
# İşlenen görüntüler kaydedildi: 2_processed_1177.png
# İşlenen görüntüler kaydedildi: 2_processed_1178.png
# İşlenen görüntüler kaydedildi: 2_processed_1179.png
# İşlenen görüntüler kaydedildi: 2_processed_118.png
# İşlenen görüntüler kaydedildi: 2_processed_1180.png
# İşlenen görüntüler kaydedildi: 2_processed_1181.png
# İşlenen görüntüler kaydedildi: 2_processed_1182.png
# İşlenen görüntüler kaydedildi: 2_processed_1183.png
# İşlenen görüntüler kaydedildi: 2_processed_1184.png
# İşlenen görüntüler kaydedildi: 2_processed_1185.png
# İşlenen görüntüler kaydedildi: 2_processed_1186.png
# İşlenen görüntüler kaydedildi: 2_processed_1187.png
# İşlenen görüntüler kaydedildi: 2_processed_1188.png
# İşlenen görüntüler kaydedildi: 2_processed_1189.png
# İşlenen görüntüler kaydedildi: 2_processed_119.png
# İşlenen görüntüler kaydedildi: 2_processed_1190.png
# İşlenen görüntüler kaydedildi: 2_processed_1191.png
# İşlenen görüntüler kaydedildi: 2_processed_1192.png
# İşlenen görüntüler kaydedildi: 2_processed_1193.png
# İşlenen görüntüler kaydedildi: 2_processed_1194.png
# İşlenen görüntüler kaydedildi: 2_processed_1195.png
# İşlenen görüntüler kaydedildi: 2_processed_1196.png
# İşlenen görüntüler kaydedildi: 2_processed_1197.png
# İşlenen görüntüler kaydedildi: 2_processed_1198.png
# İşlenen görüntüler kaydedildi: 2_processed_1199.png
# İşlenen görüntüler kaydedildi: 2_processed_12.png
# İşlenen görüntüler kaydedildi: 2_processed_120.png
# İşlenen görüntüler kaydedildi: 2_processed_1200.png
# İşlenen görüntüler kaydedildi: 2_processed_1201.png
# İşlenen görüntüler kaydedildi: 2_processed_1202.png
# İşlenen görüntüler kaydedildi: 2_processed_1203.png
# İşlenen görüntüler kaydedildi: 2_processed_1204.png
# İşlenen görüntüler kaydedildi: 2_processed_1205.png
# İşlenen görüntüler kaydedildi: 2_processed_1206.png
# İşlenen görüntüler kaydedildi: 2_processed_1207.png
# İşlenen görüntüler kaydedildi: 2_processed_1208.png
# İşlenen görüntüler kaydedildi: 2_processed_1209.png
# İşlenen görüntüler kaydedildi: 2_processed_121.png
# İşlenen görüntüler kaydedildi: 2_processed_1210.png
# İşlenen görüntüler kaydedildi: 2_processed_1211.png
# İşlenen görüntüler kaydedildi: 2_processed_1212.png
# İşlenen görüntüler kaydedildi: 2_processed_1213.png
# İşlenen görüntüler kaydedildi: 2_processed_1214.png
# İşlenen görüntüler kaydedildi: 2_processed_1215.png
# İşlenen görüntüler kaydedildi: 2_processed_1216.png
# İşlenen görüntüler kaydedildi: 2_processed_1217.png
# İşlenen görüntüler kaydedildi: 2_processed_1218.png
# İşlenen görüntüler kaydedildi: 2_processed_1219.png
# İşlenen görüntüler kaydedildi: 2_processed_122.png
# İşlenen görüntüler kaydedildi: 2_processed_1220.png
# İşlenen görüntüler kaydedildi: 2_processed_1221.png
# İşlenen görüntüler kaydedildi: 2_processed_1222.png
# İşlenen görüntüler kaydedildi: 2_processed_1223.png
# İşlenen görüntüler kaydedildi: 2_processed_1224.png
# İşlenen görüntüler kaydedildi: 2_processed_1225.png
# İşlenen görüntüler kaydedildi: 2_processed_1226.png
# İşlenen görüntüler kaydedildi: 2_processed_1227.png
# İşlenen görüntüler kaydedildi: 2_processed_1228.png
# İşlenen görüntüler kaydedildi: 2_processed_1229.png
# İşlenen görüntüler kaydedildi: 2_processed_123.png
# İşlenen görüntüler kaydedildi: 2_processed_1230.png
# İşlenen görüntüler kaydedildi: 2_processed_1231.png
# İşlenen görüntüler kaydedildi: 2_processed_1232.png
# İşlenen görüntüler kaydedildi: 2_processed_1233.png
# İşlenen görüntüler kaydedildi: 2_processed_1234.png
# İşlenen görüntüler kaydedildi: 2_processed_1235.png
# İşlenen görüntüler kaydedildi: 2_processed_1236.png
# İşlenen görüntüler kaydedildi: 2_processed_1237.png
# İşlenen görüntüler kaydedildi: 2_processed_1238.png
# İşlenen görüntüler kaydedildi: 2_processed_1239.png
# İşlenen görüntüler kaydedildi: 2_processed_124.png
# İşlenen görüntüler kaydedildi: 2_processed_1240.png
# İşlenen görüntüler kaydedildi: 2_processed_1241.png
# İşlenen görüntüler kaydedildi: 2_processed_1242.png
# İşlenen görüntüler kaydedildi: 2_processed_1243.png
# İşlenen görüntüler kaydedildi: 2_processed_1244.png
# İşlenen görüntüler kaydedildi: 2_processed_1245.png
# İşlenen görüntüler kaydedildi: 2_processed_1246.png
# İşlenen görüntüler kaydedildi: 2_processed_1247.png
# İşlenen görüntüler kaydedildi: 2_processed_1248.png
# İşlenen görüntüler kaydedildi: 2_processed_1249.png
# İşlenen görüntüler kaydedildi: 2_processed_125.png
# İşlenen görüntüler kaydedildi: 2_processed_1250.png
# İşlenen görüntüler kaydedildi: 2_processed_1251.png
# İşlenen görüntüler kaydedildi: 2_processed_1252.png
# İşlenen görüntüler kaydedildi: 2_processed_1253.png
# İşlenen görüntüler kaydedildi: 2_processed_1254.png
# İşlenen görüntüler kaydedildi: 2_processed_1255.png
# İşlenen görüntüler kaydedildi: 2_processed_1256.png
# İşlenen görüntüler kaydedildi: 2_processed_1257.png
# İşlenen görüntüler kaydedildi: 2_processed_1258.png
# İşlenen görüntüler kaydedildi: 2_processed_1259.png
# İşlenen görüntüler kaydedildi: 2_processed_126.png
# İşlenen görüntüler kaydedildi: 2_processed_1260.png
# İşlenen görüntüler kaydedildi: 2_processed_1261.png
# İşlenen görüntüler kaydedildi: 2_processed_1262.png
# İşlenen görüntüler kaydedildi: 2_processed_1263.png
# İşlenen görüntüler kaydedildi: 2_processed_1264.png
# İşlenen görüntüler kaydedildi: 2_processed_1265.png
# İşlenen görüntüler kaydedildi: 2_processed_1266.png
# İşlenen görüntüler kaydedildi: 2_processed_1267.png
# İşlenen görüntüler kaydedildi: 2_processed_1268.png
# İşlenen görüntüler kaydedildi: 2_processed_1269.png
# İşlenen görüntüler kaydedildi: 2_processed_127.png
# İşlenen görüntüler kaydedildi: 2_processed_1270.png
# İşlenen görüntüler kaydedildi: 2_processed_1271.png
# İşlenen görüntüler kaydedildi: 2_processed_1272.png
# İşlenen görüntüler kaydedildi: 2_processed_1273.png
# İşlenen görüntüler kaydedildi: 2_processed_1274.png
# İşlenen görüntüler kaydedildi: 2_processed_1275.png
# İşlenen görüntüler kaydedildi: 2_processed_1276.png
# İşlenen görüntüler kaydedildi: 2_processed_1277.png
# İşlenen görüntüler kaydedildi: 2_processed_1278.png
# İşlenen görüntüler kaydedildi: 2_processed_1279.png
# İşlenen görüntüler kaydedildi: 2_processed_128.png
# İşlenen görüntüler kaydedildi: 2_processed_1280.png
# İşlenen görüntüler kaydedildi: 2_processed_1281.png
# İşlenen görüntüler kaydedildi: 2_processed_1282.png
# İşlenen görüntüler kaydedildi: 2_processed_1283.png
# İşlenen görüntüler kaydedildi: 2_processed_1284.png
# İşlenen görüntüler kaydedildi: 2_processed_1285.png
# İşlenen görüntüler kaydedildi: 2_processed_1286.png
# İşlenen görüntüler kaydedildi: 2_processed_1287.png
# İşlenen görüntüler kaydedildi: 2_processed_1288.png
# İşlenen görüntüler kaydedildi: 2_processed_1289.png
# İşlenen görüntüler kaydedildi: 2_processed_129.png
# İşlenen görüntüler kaydedildi: 2_processed_1290.png
# İşlenen görüntüler kaydedildi: 2_processed_1291.png
# İşlenen görüntüler kaydedildi: 2_processed_1292.png
# İşlenen görüntüler kaydedildi: 2_processed_1293.png
# İşlenen görüntüler kaydedildi: 2_processed_1294.png
# İşlenen görüntüler kaydedildi: 2_processed_1295.png
# İşlenen görüntüler kaydedildi: 2_processed_1296.png
# İşlenen görüntüler kaydedildi: 2_processed_1297.png
# İşlenen görüntüler kaydedildi: 2_processed_1298.png
# İşlenen görüntüler kaydedildi: 2_processed_1299.png
# İşlenen görüntüler kaydedildi: 2_processed_13.png
# İşlenen görüntüler kaydedildi: 2_processed_130.png
# İşlenen görüntüler kaydedildi: 2_processed_1300.png
# İşlenen görüntüler kaydedildi: 2_processed_1301.png
# İşlenen görüntüler kaydedildi: 2_processed_1302.png
# İşlenen görüntüler kaydedildi: 2_processed_1303.png
# İşlenen görüntüler kaydedildi: 2_processed_1304.png
# İşlenen görüntüler kaydedildi: 2_processed_1305.png
# İşlenen görüntüler kaydedildi: 2_processed_1306.png
# İşlenen görüntüler kaydedildi: 2_processed_1307.png
# İşlenen görüntüler kaydedildi: 2_processed_1308.png
# İşlenen görüntüler kaydedildi: 2_processed_1309.png
# İşlenen görüntüler kaydedildi: 2_processed_131.png
# İşlenen görüntüler kaydedildi: 2_processed_1310.png
# İşlenen görüntüler kaydedildi: 2_processed_1311.png
# İşlenen görüntüler kaydedildi: 2_processed_1312.png
# İşlenen görüntüler kaydedildi: 2_processed_1313.png
# İşlenen görüntüler kaydedildi: 2_processed_1314.png
# İşlenen görüntüler kaydedildi: 2_processed_1315.png
# İşlenen görüntüler kaydedildi: 2_processed_1316.png
# İşlenen görüntüler kaydedildi: 2_processed_1317.png
# İşlenen görüntüler kaydedildi: 2_processed_1318.png
# İşlenen görüntüler kaydedildi: 2_processed_1319.png
# İşlenen görüntüler kaydedildi: 2_processed_132.png
# İşlenen görüntüler kaydedildi: 2_processed_1320.png
# İşlenen görüntüler kaydedildi: 2_processed_1321.png
# İşlenen görüntüler kaydedildi: 2_processed_1322.png
# İşlenen görüntüler kaydedildi: 2_processed_1323.png
# İşlenen görüntüler kaydedildi: 2_processed_1324.png
# İşlenen görüntüler kaydedildi: 2_processed_1325.png
# İşlenen görüntüler kaydedildi: 2_processed_1326.png
# İşlenen görüntüler kaydedildi: 2_processed_1327.png
# İşlenen görüntüler kaydedildi: 2_processed_1328.png
# İşlenen görüntüler kaydedildi: 2_processed_1329.png
# İşlenen görüntüler kaydedildi: 2_processed_133.png
# İşlenen görüntüler kaydedildi: 2_processed_1330.png
# İşlenen görüntüler kaydedildi: 2_processed_1331.png
# İşlenen görüntüler kaydedildi: 2_processed_1332.png
# İşlenen görüntüler kaydedildi: 2_processed_1333.png
# İşlenen görüntüler kaydedildi: 2_processed_1334.png
# İşlenen görüntüler kaydedildi: 2_processed_1335.png
# İşlenen görüntüler kaydedildi: 2_processed_1336.png
# İşlenen görüntüler kaydedildi: 2_processed_1337.png
# İşlenen görüntüler kaydedildi: 2_processed_1338.png
# İşlenen görüntüler kaydedildi: 2_processed_1339.png
# İşlenen görüntüler kaydedildi: 2_processed_134.png
# İşlenen görüntüler kaydedildi: 2_processed_1340.png
# İşlenen görüntüler kaydedildi: 2_processed_1341.png
# İşlenen görüntüler kaydedildi: 2_processed_1342.png
# İşlenen görüntüler kaydedildi: 2_processed_1343.png
# İşlenen görüntüler kaydedildi: 2_processed_1344.png
# İşlenen görüntüler kaydedildi: 2_processed_1345.png
# İşlenen görüntüler kaydedildi: 2_processed_1346.png
# İşlenen görüntüler kaydedildi: 2_processed_1347.png
# İşlenen görüntüler kaydedildi: 2_processed_1348.png
# İşlenen görüntüler kaydedildi: 2_processed_1349.png
# İşlenen görüntüler kaydedildi: 2_processed_135.png
# İşlenen görüntüler kaydedildi: 2_processed_1350.png
# İşlenen görüntüler kaydedildi: 2_processed_1351.png
# İşlenen görüntüler kaydedildi: 2_processed_1352.png
# İşlenen görüntüler kaydedildi: 2_processed_1353.png
# İşlenen görüntüler kaydedildi: 2_processed_1354.png
# İşlenen görüntüler kaydedildi: 2_processed_1355.png
# İşlenen görüntüler kaydedildi: 2_processed_1356.png
# İşlenen görüntüler kaydedildi: 2_processed_1357.png
# İşlenen görüntüler kaydedildi: 2_processed_1358.png
# İşlenen görüntüler kaydedildi: 2_processed_1359.png
# İşlenen görüntüler kaydedildi: 2_processed_136.png
# İşlenen görüntüler kaydedildi: 2_processed_1360.png
# İşlenen görüntüler kaydedildi: 2_processed_1361.png
# İşlenen görüntüler kaydedildi: 2_processed_1362.png
# İşlenen görüntüler kaydedildi: 2_processed_1363.png
# İşlenen görüntüler kaydedildi: 2_processed_1364.png
# İşlenen görüntüler kaydedildi: 2_processed_1365.png
# İşlenen görüntüler kaydedildi: 2_processed_1366.png
# İşlenen görüntüler kaydedildi: 2_processed_1367.png
# İşlenen görüntüler kaydedildi: 2_processed_1368.png
# İşlenen görüntüler kaydedildi: 2_processed_1369.png
# İşlenen görüntüler kaydedildi: 2_processed_137.png
# İşlenen görüntüler kaydedildi: 2_processed_1370.png
# İşlenen görüntüler kaydedildi: 2_processed_1371.png
# İşlenen görüntüler kaydedildi: 2_processed_1372.png
# İşlenen görüntüler kaydedildi: 2_processed_1373.png
# İşlenen görüntüler kaydedildi: 2_processed_1374.png
# İşlenen görüntüler kaydedildi: 2_processed_1375.png
# İşlenen görüntüler kaydedildi: 2_processed_1376.png
# İşlenen görüntüler kaydedildi: 2_processed_1377.png
# İşlenen görüntüler kaydedildi: 2_processed_1378.png
# İşlenen görüntüler kaydedildi: 2_processed_1379.png
# İşlenen görüntüler kaydedildi: 2_processed_138.png
# İşlenen görüntüler kaydedildi: 2_processed_1380.png
# İşlenen görüntüler kaydedildi: 2_processed_1381.png
# İşlenen görüntüler kaydedildi: 2_processed_1382.png
# İşlenen görüntüler kaydedildi: 2_processed_1383.png
# İşlenen görüntüler kaydedildi: 2_processed_1384.png
# İşlenen görüntüler kaydedildi: 2_processed_1385.png
# İşlenen görüntüler kaydedildi: 2_processed_1386.png
# İşlenen görüntüler kaydedildi: 2_processed_1387.png
# İşlenen görüntüler kaydedildi: 2_processed_1388.png
# İşlenen görüntüler kaydedildi: 2_processed_1389.png
# İşlenen görüntüler kaydedildi: 2_processed_139.png
# İşlenen görüntüler kaydedildi: 2_processed_1390.png
# İşlenen görüntüler kaydedildi: 2_processed_1391.png
# İşlenen görüntüler kaydedildi: 2_processed_1392.png
# İşlenen görüntüler kaydedildi: 2_processed_1393.png
# İşlenen görüntüler kaydedildi: 2_processed_1394.png
# İşlenen görüntüler kaydedildi: 2_processed_1395.png
# İşlenen görüntüler kaydedildi: 2_processed_1396.png
# İşlenen görüntüler kaydedildi: 2_processed_1397.png
# İşlenen görüntüler kaydedildi: 2_processed_1398.png
# İşlenen görüntüler kaydedildi: 2_processed_1399.png
# İşlenen görüntüler kaydedildi: 2_processed_14.png
# İşlenen görüntüler kaydedildi: 2_processed_140.png
# İşlenen görüntüler kaydedildi: 2_processed_1400.png
# İşlenen görüntüler kaydedildi: 2_processed_1401.png
# İşlenen görüntüler kaydedildi: 2_processed_1402.png
# İşlenen görüntüler kaydedildi: 2_processed_1403.png
# İşlenen görüntüler kaydedildi: 2_processed_1404.png
# İşlenen görüntüler kaydedildi: 2_processed_1405.png
# İşlenen görüntüler kaydedildi: 2_processed_1406.png
# İşlenen görüntüler kaydedildi: 2_processed_1407.png
# İşlenen görüntüler kaydedildi: 2_processed_1408.png
# İşlenen görüntüler kaydedildi: 2_processed_1409.png
# İşlenen görüntüler kaydedildi: 2_processed_141.png
# İşlenen görüntüler kaydedildi: 2_processed_1410.png
# İşlenen görüntüler kaydedildi: 2_processed_1411.png
# İşlenen görüntüler kaydedildi: 2_processed_1412.png
# İşlenen görüntüler kaydedildi: 2_processed_1413.png
# İşlenen görüntüler kaydedildi: 2_processed_1414.png
# İşlenen görüntüler kaydedildi: 2_processed_1415.png
# İşlenen görüntüler kaydedildi: 2_processed_1416.png
# İşlenen görüntüler kaydedildi: 2_processed_1417.png
# İşlenen görüntüler kaydedildi: 2_processed_1418.png
# İşlenen görüntüler kaydedildi: 2_processed_1419.png
# İşlenen görüntüler kaydedildi: 2_processed_142.png
# İşlenen görüntüler kaydedildi: 2_processed_1420.png
# İşlenen görüntüler kaydedildi: 2_processed_1421.png
# İşlenen görüntüler kaydedildi: 2_processed_1422.png
# İşlenen görüntüler kaydedildi: 2_processed_1423.png
# İşlenen görüntüler kaydedildi: 2_processed_1424.png
# İşlenen görüntüler kaydedildi: 2_processed_1425.png
# İşlenen görüntüler kaydedildi: 2_processed_1426.png
# İşlenen görüntüler kaydedildi: 2_processed_1427.png
# İşlenen görüntüler kaydedildi: 2_processed_1428.png
# İşlenen görüntüler kaydedildi: 2_processed_1429.png
# İşlenen görüntüler kaydedildi: 2_processed_143.png
# İşlenen görüntüler kaydedildi: 2_processed_1430.png
# İşlenen görüntüler kaydedildi: 2_processed_1431.png
# İşlenen görüntüler kaydedildi: 2_processed_1432.png
# İşlenen görüntüler kaydedildi: 2_processed_1433.png
# İşlenen görüntüler kaydedildi: 2_processed_1434.png
# İşlenen görüntüler kaydedildi: 2_processed_1435.png
# İşlenen görüntüler kaydedildi: 2_processed_1436.png
# İşlenen görüntüler kaydedildi: 2_processed_1437.png
# İşlenen görüntüler kaydedildi: 2_processed_1438.png
# İşlenen görüntüler kaydedildi: 2_processed_1439.png
# İşlenen görüntüler kaydedildi: 2_processed_144.png
# İşlenen görüntüler kaydedildi: 2_processed_1440.png
# İşlenen görüntüler kaydedildi: 2_processed_1441.png
# İşlenen görüntüler kaydedildi: 2_processed_1442.png
# İşlenen görüntüler kaydedildi: 2_processed_1443.png
# İşlenen görüntüler kaydedildi: 2_processed_1444.png
# İşlenen görüntüler kaydedildi: 2_processed_1445.png
# İşlenen görüntüler kaydedildi: 2_processed_1446.png
# İşlenen görüntüler kaydedildi: 2_processed_1447.png
# İşlenen görüntüler kaydedildi: 2_processed_1448.png
# İşlenen görüntüler kaydedildi: 2_processed_1449.png
# İşlenen görüntüler kaydedildi: 2_processed_145.png
# İşlenen görüntüler kaydedildi: 2_processed_1450.png
# İşlenen görüntüler kaydedildi: 2_processed_1451.png
# İşlenen görüntüler kaydedildi: 2_processed_1452.png
# İşlenen görüntüler kaydedildi: 2_processed_1453.png
# İşlenen görüntüler kaydedildi: 2_processed_1454.png
# İşlenen görüntüler kaydedildi: 2_processed_1455.png
# İşlenen görüntüler kaydedildi: 2_processed_1456.png
# İşlenen görüntüler kaydedildi: 2_processed_1457.png
# İşlenen görüntüler kaydedildi: 2_processed_1458.png
# İşlenen görüntüler kaydedildi: 2_processed_1459.png
# İşlenen görüntüler kaydedildi: 2_processed_146.png
# İşlenen görüntüler kaydedildi: 2_processed_1460.png
# İşlenen görüntüler kaydedildi: 2_processed_1461.png
# İşlenen görüntüler kaydedildi: 2_processed_1462.png
# İşlenen görüntüler kaydedildi: 2_processed_1463.png
# İşlenen görüntüler kaydedildi: 2_processed_1464.png
# İşlenen görüntüler kaydedildi: 2_processed_1465.png
# İşlenen görüntüler kaydedildi: 2_processed_1466.png
# İşlenen görüntüler kaydedildi: 2_processed_1467.png
# İşlenen görüntüler kaydedildi: 2_processed_1468.png
# İşlenen görüntüler kaydedildi: 2_processed_1469.png
# İşlenen görüntüler kaydedildi: 2_processed_147.png
# İşlenen görüntüler kaydedildi: 2_processed_1470.png
# İşlenen görüntüler kaydedildi: 2_processed_1471.png
# İşlenen görüntüler kaydedildi: 2_processed_1472.png
# İşlenen görüntüler kaydedildi: 2_processed_1473.png
# İşlenen görüntüler kaydedildi: 2_processed_1474.png
# İşlenen görüntüler kaydedildi: 2_processed_1475.png
# İşlenen görüntüler kaydedildi: 2_processed_1476.png
# İşlenen görüntüler kaydedildi: 2_processed_1477.png
# İşlenen görüntüler kaydedildi: 2_processed_1478.png
# İşlenen görüntüler kaydedildi: 2_processed_1479.png
# İşlenen görüntüler kaydedildi: 2_processed_148.png
# İşlenen görüntüler kaydedildi: 2_processed_1480.png
# İşlenen görüntüler kaydedildi: 2_processed_1481.png
# İşlenen görüntüler kaydedildi: 2_processed_1482.png
# İşlenen görüntüler kaydedildi: 2_processed_1483.png
# İşlenen görüntüler kaydedildi: 2_processed_1484.png
# İşlenen görüntüler kaydedildi: 2_processed_1485.png
# İşlenen görüntüler kaydedildi: 2_processed_1486.png
# İşlenen görüntüler kaydedildi: 2_processed_1487.png
# İşlenen görüntüler kaydedildi: 2_processed_1488.png
# İşlenen görüntüler kaydedildi: 2_processed_1489.png
# İşlenen görüntüler kaydedildi: 2_processed_149.png
# İşlenen görüntüler kaydedildi: 2_processed_1490.png
# İşlenen görüntüler kaydedildi: 2_processed_1491.png
# İşlenen görüntüler kaydedildi: 2_processed_1492.png
# İşlenen görüntüler kaydedildi: 2_processed_1493.png
# İşlenen görüntüler kaydedildi: 2_processed_1494.png
# İşlenen görüntüler kaydedildi: 2_processed_1495.png
# İşlenen görüntüler kaydedildi: 2_processed_1496.png
# İşlenen görüntüler kaydedildi: 2_processed_1497.png
# İşlenen görüntüler kaydedildi: 2_processed_1498.png
# İşlenen görüntüler kaydedildi: 2_processed_1499.png
# İşlenen görüntüler kaydedildi: 2_processed_15.png
# İşlenen görüntüler kaydedildi: 2_processed_150.png
# İşlenen görüntüler kaydedildi: 2_processed_1500.png
# İşlenen görüntüler kaydedildi: 2_processed_1501.png
# İşlenen görüntüler kaydedildi: 2_processed_1502.png
# İşlenen görüntüler kaydedildi: 2_processed_1503.png
# İşlenen görüntüler kaydedildi: 2_processed_1504.png
# İşlenen görüntüler kaydedildi: 2_processed_1505.png
# İşlenen görüntüler kaydedildi: 2_processed_1506.png
# İşlenen görüntüler kaydedildi: 2_processed_1507.png
# İşlenen görüntüler kaydedildi: 2_processed_1508.png
# İşlenen görüntüler kaydedildi: 2_processed_1509.png
# İşlenen görüntüler kaydedildi: 2_processed_151.png
# İşlenen görüntüler kaydedildi: 2_processed_1510.png
# İşlenen görüntüler kaydedildi: 2_processed_1511.png
# İşlenen görüntüler kaydedildi: 2_processed_1512.png
# İşlenen görüntüler kaydedildi: 2_processed_1513.png
# İşlenen görüntüler kaydedildi: 2_processed_1514.png
# İşlenen görüntüler kaydedildi: 2_processed_1515.png
# İşlenen görüntüler kaydedildi: 2_processed_1516.png
# İşlenen görüntüler kaydedildi: 2_processed_1517.png
# İşlenen görüntüler kaydedildi: 2_processed_1518.png
# İşlenen görüntüler kaydedildi: 2_processed_1519.png
# İşlenen görüntüler kaydedildi: 2_processed_152.png
# İşlenen görüntüler kaydedildi: 2_processed_1520.png
# İşlenen görüntüler kaydedildi: 2_processed_1521.png
# İşlenen görüntüler kaydedildi: 2_processed_1522.png
# İşlenen görüntüler kaydedildi: 2_processed_1523.png
# İşlenen görüntüler kaydedildi: 2_processed_1524.png
# İşlenen görüntüler kaydedildi: 2_processed_1525.png
# İşlenen görüntüler kaydedildi: 2_processed_1526.png
# İşlenen görüntüler kaydedildi: 2_processed_1527.png
# İşlenen görüntüler kaydedildi: 2_processed_1528.png
# İşlenen görüntüler kaydedildi: 2_processed_1529.png
# İşlenen görüntüler kaydedildi: 2_processed_153.png
# İşlenen görüntüler kaydedildi: 2_processed_1530.png
# İşlenen görüntüler kaydedildi: 2_processed_1531.png
# İşlenen görüntüler kaydedildi: 2_processed_1532.png
# İşlenen görüntüler kaydedildi: 2_processed_1533.png
# İşlenen görüntüler kaydedildi: 2_processed_1534.png
# İşlenen görüntüler kaydedildi: 2_processed_1535.png
# İşlenen görüntüler kaydedildi: 2_processed_1536.png
# İşlenen görüntüler kaydedildi: 2_processed_1537.png
# İşlenen görüntüler kaydedildi: 2_processed_1538.png
# İşlenen görüntüler kaydedildi: 2_processed_1539.png
# İşlenen görüntüler kaydedildi: 2_processed_154.png
# İşlenen görüntüler kaydedildi: 2_processed_1540.png
# İşlenen görüntüler kaydedildi: 2_processed_1541.png
# İşlenen görüntüler kaydedildi: 2_processed_1542.png
# İşlenen görüntüler kaydedildi: 2_processed_1543.png
# İşlenen görüntüler kaydedildi: 2_processed_1544.png
# İşlenen görüntüler kaydedildi: 2_processed_1545.png
# İşlenen görüntüler kaydedildi: 2_processed_1546.png
# İşlenen görüntüler kaydedildi: 2_processed_1547.png
# İşlenen görüntüler kaydedildi: 2_processed_1548.png
# İşlenen görüntüler kaydedildi: 2_processed_1549.png
# İşlenen görüntüler kaydedildi: 2_processed_155.png
# İşlenen görüntüler kaydedildi: 2_processed_1550.png
# İşlenen görüntüler kaydedildi: 2_processed_1551.png
# İşlenen görüntüler kaydedildi: 2_processed_1552.png
# İşlenen görüntüler kaydedildi: 2_processed_1553.png
# İşlenen görüntüler kaydedildi: 2_processed_1554.png
# İşlenen görüntüler kaydedildi: 2_processed_1555.png
# İşlenen görüntüler kaydedildi: 2_processed_1556.png
# İşlenen görüntüler kaydedildi: 2_processed_1557.png
# İşlenen görüntüler kaydedildi: 2_processed_1558.png
# İşlenen görüntüler kaydedildi: 2_processed_1559.png
# İşlenen görüntüler kaydedildi: 2_processed_156.png
# İşlenen görüntüler kaydedildi: 2_processed_1560.png
# İşlenen görüntüler kaydedildi: 2_processed_1561.png
# İşlenen görüntüler kaydedildi: 2_processed_1562.png
# İşlenen görüntüler kaydedildi: 2_processed_1563.png
# İşlenen görüntüler kaydedildi: 2_processed_1564.png
# İşlenen görüntüler kaydedildi: 2_processed_1565.png
# İşlenen görüntüler kaydedildi: 2_processed_1566.png
# İşlenen görüntüler kaydedildi: 2_processed_1567.png
# İşlenen görüntüler kaydedildi: 2_processed_1568.png
# İşlenen görüntüler kaydedildi: 2_processed_1569.png
# İşlenen görüntüler kaydedildi: 2_processed_157.png
# İşlenen görüntüler kaydedildi: 2_processed_1570.png
# İşlenen görüntüler kaydedildi: 2_processed_1571.png
# İşlenen görüntüler kaydedildi: 2_processed_1572.png
# İşlenen görüntüler kaydedildi: 2_processed_1573.png
# İşlenen görüntüler kaydedildi: 2_processed_1574.png
# İşlenen görüntüler kaydedildi: 2_processed_1575.png
# İşlenen görüntüler kaydedildi: 2_processed_1576.png
# İşlenen görüntüler kaydedildi: 2_processed_1577.png
# İşlenen görüntüler kaydedildi: 2_processed_1578.png
# İşlenen görüntüler kaydedildi: 2_processed_1579.png
# İşlenen görüntüler kaydedildi: 2_processed_158.png
# İşlenen görüntüler kaydedildi: 2_processed_1580.png
# İşlenen görüntüler kaydedildi: 2_processed_1581.png
# İşlenen görüntüler kaydedildi: 2_processed_1582.png
# İşlenen görüntüler kaydedildi: 2_processed_1583.png
# İşlenen görüntüler kaydedildi: 2_processed_1584.png
# İşlenen görüntüler kaydedildi: 2_processed_1585.png
# İşlenen görüntüler kaydedildi: 2_processed_1586.png
# İşlenen görüntüler kaydedildi: 2_processed_1587.png
# İşlenen görüntüler kaydedildi: 2_processed_1588.png
# İşlenen görüntüler kaydedildi: 2_processed_1589.png
# İşlenen görüntüler kaydedildi: 2_processed_159.png
# İşlenen görüntüler kaydedildi: 2_processed_1590.png
# İşlenen görüntüler kaydedildi: 2_processed_1591.png
# İşlenen görüntüler kaydedildi: 2_processed_1592.png
# İşlenen görüntüler kaydedildi: 2_processed_1593.png
# İşlenen görüntüler kaydedildi: 2_processed_1594.png
# İşlenen görüntüler kaydedildi: 2_processed_1595.png
# İşlenen görüntüler kaydedildi: 2_processed_1596.png
# İşlenen görüntüler kaydedildi: 2_processed_1597.png
# İşlenen görüntüler kaydedildi: 2_processed_1598.png
# İşlenen görüntüler kaydedildi: 2_processed_1599.png
# İşlenen görüntüler kaydedildi: 2_processed_16.png
# İşlenen görüntüler kaydedildi: 2_processed_160.png
# İşlenen görüntüler kaydedildi: 2_processed_1600.png
# İşlenen görüntüler kaydedildi: 2_processed_1601.png
# İşlenen görüntüler kaydedildi: 2_processed_1602.png
# İşlenen görüntüler kaydedildi: 2_processed_1603.png
# İşlenen görüntüler kaydedildi: 2_processed_1604.png
# İşlenen görüntüler kaydedildi: 2_processed_1605.png
# İşlenen görüntüler kaydedildi: 2_processed_1606.png
# İşlenen görüntüler kaydedildi: 2_processed_1607.png
# İşlenen görüntüler kaydedildi: 2_processed_1608.png
# İşlenen görüntüler kaydedildi: 2_processed_1609.png
# İşlenen görüntüler kaydedildi: 2_processed_161.png
# İşlenen görüntüler kaydedildi: 2_processed_1610.png
# İşlenen görüntüler kaydedildi: 2_processed_1611.png
# İşlenen görüntüler kaydedildi: 2_processed_1612.png
# İşlenen görüntüler kaydedildi: 2_processed_1613.png
# İşlenen görüntüler kaydedildi: 2_processed_1614.png
# İşlenen görüntüler kaydedildi: 2_processed_1615.png
# İşlenen görüntüler kaydedildi: 2_processed_1616.png
# İşlenen görüntüler kaydedildi: 2_processed_1617.png
# İşlenen görüntüler kaydedildi: 2_processed_1618.png
# İşlenen görüntüler kaydedildi: 2_processed_1619.png
# İşlenen görüntüler kaydedildi: 2_processed_162.png
# İşlenen görüntüler kaydedildi: 2_processed_1620.png
# İşlenen görüntüler kaydedildi: 2_processed_1621.png
# İşlenen görüntüler kaydedildi: 2_processed_1622.png
# İşlenen görüntüler kaydedildi: 2_processed_1623.png
# İşlenen görüntüler kaydedildi: 2_processed_1624.png
# İşlenen görüntüler kaydedildi: 2_processed_1625.png
# İşlenen görüntüler kaydedildi: 2_processed_1626.png
# İşlenen görüntüler kaydedildi: 2_processed_1627.png
# İşlenen görüntüler kaydedildi: 2_processed_1628.png
# İşlenen görüntüler kaydedildi: 2_processed_1629.png
# İşlenen görüntüler kaydedildi: 2_processed_163.png
# İşlenen görüntüler kaydedildi: 2_processed_1630.png
# İşlenen görüntüler kaydedildi: 2_processed_1631.png
# İşlenen görüntüler kaydedildi: 2_processed_1632.png
# İşlenen görüntüler kaydedildi: 2_processed_1633.png
# İşlenen görüntüler kaydedildi: 2_processed_1634.png
# İşlenen görüntüler kaydedildi: 2_processed_1635.png
# İşlenen görüntüler kaydedildi: 2_processed_1636.png
# İşlenen görüntüler kaydedildi: 2_processed_1637.png
# İşlenen görüntüler kaydedildi: 2_processed_1638.png
# İşlenen görüntüler kaydedildi: 2_processed_1639.png
# İşlenen görüntüler kaydedildi: 2_processed_164.png
# İşlenen görüntüler kaydedildi: 2_processed_1640.png
# İşlenen görüntüler kaydedildi: 2_processed_1641.png
# İşlenen görüntüler kaydedildi: 2_processed_1642.png
# İşlenen görüntüler kaydedildi: 2_processed_1643.png
# İşlenen görüntüler kaydedildi: 2_processed_1644.png
# İşlenen görüntüler kaydedildi: 2_processed_1645.png
# İşlenen görüntüler kaydedildi: 2_processed_1646.png
# İşlenen görüntüler kaydedildi: 2_processed_1647.png
# İşlenen görüntüler kaydedildi: 2_processed_1648.png
# İşlenen görüntüler kaydedildi: 2_processed_1649.png
# İşlenen görüntüler kaydedildi: 2_processed_165.png
# İşlenen görüntüler kaydedildi: 2_processed_1650.png
# İşlenen görüntüler kaydedildi: 2_processed_1651.png
# İşlenen görüntüler kaydedildi: 2_processed_1652.png
# İşlenen görüntüler kaydedildi: 2_processed_1653.png
# İşlenen görüntüler kaydedildi: 2_processed_1654.png
# İşlenen görüntüler kaydedildi: 2_processed_1655.png
# İşlenen görüntüler kaydedildi: 2_processed_1656.png
# İşlenen görüntüler kaydedildi: 2_processed_1657.png
# İşlenen görüntüler kaydedildi: 2_processed_1658.png
# İşlenen görüntüler kaydedildi: 2_processed_1659.png
# İşlenen görüntüler kaydedildi: 2_processed_166.png
# İşlenen görüntüler kaydedildi: 2_processed_1660.png
# İşlenen görüntüler kaydedildi: 2_processed_1661.png
# İşlenen görüntüler kaydedildi: 2_processed_1662.png
# İşlenen görüntüler kaydedildi: 2_processed_1663.png
# İşlenen görüntüler kaydedildi: 2_processed_1664.png
# İşlenen görüntüler kaydedildi: 2_processed_1665.png
# İşlenen görüntüler kaydedildi: 2_processed_1666.png
# İşlenen görüntüler kaydedildi: 2_processed_1667.png
# İşlenen görüntüler kaydedildi: 2_processed_1668.png
# İşlenen görüntüler kaydedildi: 2_processed_1669.png
# İşlenen görüntüler kaydedildi: 2_processed_167.png
# İşlenen görüntüler kaydedildi: 2_processed_1670.png
# İşlenen görüntüler kaydedildi: 2_processed_1671.png
# İşlenen görüntüler kaydedildi: 2_processed_1672.png
# İşlenen görüntüler kaydedildi: 2_processed_1673.png
# İşlenen görüntüler kaydedildi: 2_processed_1674.png
# İşlenen görüntüler kaydedildi: 2_processed_1675.png
# İşlenen görüntüler kaydedildi: 2_processed_1676.png
# İşlenen görüntüler kaydedildi: 2_processed_1677.png
# İşlenen görüntüler kaydedildi: 2_processed_1678.png
# İşlenen görüntüler kaydedildi: 2_processed_1679.png
# İşlenen görüntüler kaydedildi: 2_processed_168.png
# İşlenen görüntüler kaydedildi: 2_processed_1680.png
# İşlenen görüntüler kaydedildi: 2_processed_1681.png
# İşlenen görüntüler kaydedildi: 2_processed_1682.png
# İşlenen görüntüler kaydedildi: 2_processed_1683.png
# İşlenen görüntüler kaydedildi: 2_processed_1684.png
# İşlenen görüntüler kaydedildi: 2_processed_1685.png
# İşlenen görüntüler kaydedildi: 2_processed_1686.png
# İşlenen görüntüler kaydedildi: 2_processed_1687.png
# İşlenen görüntüler kaydedildi: 2_processed_1688.png
# İşlenen görüntüler kaydedildi: 2_processed_1689.png
# İşlenen görüntüler kaydedildi: 2_processed_169.png
# İşlenen görüntüler kaydedildi: 2_processed_1690.png
# İşlenen görüntüler kaydedildi: 2_processed_1691.png
# İşlenen görüntüler kaydedildi: 2_processed_1692.png
# İşlenen görüntüler kaydedildi: 2_processed_1693.png
# İşlenen görüntüler kaydedildi: 2_processed_1694.png
# İşlenen görüntüler kaydedildi: 2_processed_1695.png
# İşlenen görüntüler kaydedildi: 2_processed_1696.png
# İşlenen görüntüler kaydedildi: 2_processed_1697.png
# İşlenen görüntüler kaydedildi: 2_processed_1698.png
# İşlenen görüntüler kaydedildi: 2_processed_1699.png
# İşlenen görüntüler kaydedildi: 2_processed_17.png
# İşlenen görüntüler kaydedildi: 2_processed_170.png
# İşlenen görüntüler kaydedildi: 2_processed_1700.png
# İşlenen görüntüler kaydedildi: 2_processed_1701.png
# İşlenen görüntüler kaydedildi: 2_processed_1702.png
# İşlenen görüntüler kaydedildi: 2_processed_1703.png
# İşlenen görüntüler kaydedildi: 2_processed_1704.png
# İşlenen görüntüler kaydedildi: 2_processed_1705.png
# İşlenen görüntüler kaydedildi: 2_processed_1706.png
# İşlenen görüntüler kaydedildi: 2_processed_1707.png
# İşlenen görüntüler kaydedildi: 2_processed_1708.png
# İşlenen görüntüler kaydedildi: 2_processed_1709.png
# İşlenen görüntüler kaydedildi: 2_processed_171.png
# İşlenen görüntüler kaydedildi: 2_processed_1710.png
# İşlenen görüntüler kaydedildi: 2_processed_1711.png
# İşlenen görüntüler kaydedildi: 2_processed_1712.png
# İşlenen görüntüler kaydedildi: 2_processed_1713.png
# İşlenen görüntüler kaydedildi: 2_processed_1714.png
# İşlenen görüntüler kaydedildi: 2_processed_1715.png
# İşlenen görüntüler kaydedildi: 2_processed_1716.png
# İşlenen görüntüler kaydedildi: 2_processed_1717.png
# İşlenen görüntüler kaydedildi: 2_processed_1718.png
# İşlenen görüntüler kaydedildi: 2_processed_1719.png
# İşlenen görüntüler kaydedildi: 2_processed_172.png
# İşlenen görüntüler kaydedildi: 2_processed_1720.png
# İşlenen görüntüler kaydedildi: 2_processed_1721.png
# İşlenen görüntüler kaydedildi: 2_processed_1722.png
# İşlenen görüntüler kaydedildi: 2_processed_1723.png
# İşlenen görüntüler kaydedildi: 2_processed_1724.png
# İşlenen görüntüler kaydedildi: 2_processed_1725.png
# İşlenen görüntüler kaydedildi: 2_processed_1726.png
# İşlenen görüntüler kaydedildi: 2_processed_1727.png
# İşlenen görüntüler kaydedildi: 2_processed_1728.png
# İşlenen görüntüler kaydedildi: 2_processed_1729.png
# İşlenen görüntüler kaydedildi: 2_processed_173.png
# İşlenen görüntüler kaydedildi: 2_processed_1730.png
# İşlenen görüntüler kaydedildi: 2_processed_1731.png
# İşlenen görüntüler kaydedildi: 2_processed_1732.png
# İşlenen görüntüler kaydedildi: 2_processed_1733.png
# İşlenen görüntüler kaydedildi: 2_processed_1734.png
# İşlenen görüntüler kaydedildi: 2_processed_1735.png
# İşlenen görüntüler kaydedildi: 2_processed_1736.png
# İşlenen görüntüler kaydedildi: 2_processed_1737.png
# İşlenen görüntüler kaydedildi: 2_processed_1738.png
# İşlenen görüntüler kaydedildi: 2_processed_1739.png
# İşlenen görüntüler kaydedildi: 2_processed_174.png
# İşlenen görüntüler kaydedildi: 2_processed_1740.png
# İşlenen görüntüler kaydedildi: 2_processed_1741.png
# İşlenen görüntüler kaydedildi: 2_processed_1742.png
# İşlenen görüntüler kaydedildi: 2_processed_1743.png
# İşlenen görüntüler kaydedildi: 2_processed_1744.png
# İşlenen görüntüler kaydedildi: 2_processed_1745.png
# İşlenen görüntüler kaydedildi: 2_processed_1746.png
# İşlenen görüntüler kaydedildi: 2_processed_1747.png
# İşlenen görüntüler kaydedildi: 2_processed_1748.png
# İşlenen görüntüler kaydedildi: 2_processed_1749.png
# İşlenen görüntüler kaydedildi: 2_processed_175.png
# İşlenen görüntüler kaydedildi: 2_processed_1750.png
# İşlenen görüntüler kaydedildi: 2_processed_1751.png
# İşlenen görüntüler kaydedildi: 2_processed_1752.png
# İşlenen görüntüler kaydedildi: 2_processed_1753.png
# İşlenen görüntüler kaydedildi: 2_processed_1754.png
# İşlenen görüntüler kaydedildi: 2_processed_1755.png
# İşlenen görüntüler kaydedildi: 2_processed_1756.png
# İşlenen görüntüler kaydedildi: 2_processed_1757.png
# İşlenen görüntüler kaydedildi: 2_processed_1758.png
# İşlenen görüntüler kaydedildi: 2_processed_1759.png
# İşlenen görüntüler kaydedildi: 2_processed_176.png
# İşlenen görüntüler kaydedildi: 2_processed_1760.png
# İşlenen görüntüler kaydedildi: 2_processed_1761.png
# İşlenen görüntüler kaydedildi: 2_processed_1762.png
# İşlenen görüntüler kaydedildi: 2_processed_1763.png
# İşlenen görüntüler kaydedildi: 2_processed_1764.png
# İşlenen görüntüler kaydedildi: 2_processed_1765.png
# İşlenen görüntüler kaydedildi: 2_processed_1766.png
# İşlenen görüntüler kaydedildi: 2_processed_1767.png
# İşlenen görüntüler kaydedildi: 2_processed_1768.png
# İşlenen görüntüler kaydedildi: 2_processed_1769.png
# İşlenen görüntüler kaydedildi: 2_processed_177.png
# İşlenen görüntüler kaydedildi: 2_processed_1770.png
# İşlenen görüntüler kaydedildi: 2_processed_1771.png
# İşlenen görüntüler kaydedildi: 2_processed_1772.png
# İşlenen görüntüler kaydedildi: 2_processed_1773.png
# İşlenen görüntüler kaydedildi: 2_processed_1774.png
# İşlenen görüntüler kaydedildi: 2_processed_1775.png
# İşlenen görüntüler kaydedildi: 2_processed_1776.png
# İşlenen görüntüler kaydedildi: 2_processed_1777.png
# İşlenen görüntüler kaydedildi: 2_processed_1778.png
# İşlenen görüntüler kaydedildi: 2_processed_1779.png
# İşlenen görüntüler kaydedildi: 2_processed_178.png
# İşlenen görüntüler kaydedildi: 2_processed_1780.png
# İşlenen görüntüler kaydedildi: 2_processed_1781.png
# İşlenen görüntüler kaydedildi: 2_processed_1782.png
# İşlenen görüntüler kaydedildi: 2_processed_1783.png
# İşlenen görüntüler kaydedildi: 2_processed_1784.png
# İşlenen görüntüler kaydedildi: 2_processed_1785.png
# İşlenen görüntüler kaydedildi: 2_processed_1786.png
# İşlenen görüntüler kaydedildi: 2_processed_1787.png
# İşlenen görüntüler kaydedildi: 2_processed_1788.png
# İşlenen görüntüler kaydedildi: 2_processed_1789.png
# İşlenen görüntüler kaydedildi: 2_processed_179.png
# İşlenen görüntüler kaydedildi: 2_processed_1790.png
# İşlenen görüntüler kaydedildi: 2_processed_1791.png
# İşlenen görüntüler kaydedildi: 2_processed_1792.png
# İşlenen görüntüler kaydedildi: 2_processed_1793.png
# İşlenen görüntüler kaydedildi: 2_processed_1794.png
# İşlenen görüntüler kaydedildi: 2_processed_1795.png
# İşlenen görüntüler kaydedildi: 2_processed_1796.png
# İşlenen görüntüler kaydedildi: 2_processed_1797.png
# İşlenen görüntüler kaydedildi: 2_processed_1798.png
# İşlenen görüntüler kaydedildi: 2_processed_1799.png
# İşlenen görüntüler kaydedildi: 2_processed_18.png
# İşlenen görüntüler kaydedildi: 2_processed_180.png
# İşlenen görüntüler kaydedildi: 2_processed_1800.png
# İşlenen görüntüler kaydedildi: 2_processed_1801.png
# İşlenen görüntüler kaydedildi: 2_processed_1802.png
# İşlenen görüntüler kaydedildi: 2_processed_1803.png
# İşlenen görüntüler kaydedildi: 2_processed_1804.png
# İşlenen görüntüler kaydedildi: 2_processed_1805.png
# İşlenen görüntüler kaydedildi: 2_processed_1806.png
# İşlenen görüntüler kaydedildi: 2_processed_1807.png
# İşlenen görüntüler kaydedildi: 2_processed_1808.png
# İşlenen görüntüler kaydedildi: 2_processed_1809.png
# İşlenen görüntüler kaydedildi: 2_processed_181.png
# İşlenen görüntüler kaydedildi: 2_processed_1810.png
# İşlenen görüntüler kaydedildi: 2_processed_1811.png
# İşlenen görüntüler kaydedildi: 2_processed_1812.png
# İşlenen görüntüler kaydedildi: 2_processed_1813.png
# İşlenen görüntüler kaydedildi: 2_processed_1814.png
# İşlenen görüntüler kaydedildi: 2_processed_1815.png
# İşlenen görüntüler kaydedildi: 2_processed_1816.png
# İşlenen görüntüler kaydedildi: 2_processed_1817.png
# İşlenen görüntüler kaydedildi: 2_processed_1818.png
# İşlenen görüntüler kaydedildi: 2_processed_1819.png
# İşlenen görüntüler kaydedildi: 2_processed_182.png
# İşlenen görüntüler kaydedildi: 2_processed_1820.png
# İşlenen görüntüler kaydedildi: 2_processed_1821.png
# İşlenen görüntüler kaydedildi: 2_processed_1822.png
# İşlenen görüntüler kaydedildi: 2_processed_1823.png
# İşlenen görüntüler kaydedildi: 2_processed_1824.png
# İşlenen görüntüler kaydedildi: 2_processed_1825.png
# İşlenen görüntüler kaydedildi: 2_processed_1826.png
# İşlenen görüntüler kaydedildi: 2_processed_1827.png
# İşlenen görüntüler kaydedildi: 2_processed_1828.png
# İşlenen görüntüler kaydedildi: 2_processed_1829.png
# İşlenen görüntüler kaydedildi: 2_processed_183.png
# İşlenen görüntüler kaydedildi: 2_processed_1830.png
# ...
# İşlenen görüntüler kaydedildi: 2_processed_716.png
# İşlenen görüntüler kaydedildi: 2_processed_717.png
# İşlenen görüntüler kaydedildi: 2_processed_718.png
# İşlenen görüntüler kaydedildi: 2_processed_719.png
# İşlenen görüntüler kaydedildi: 2_processed_72.png
# İşlenen görüntüler kaydedildi: 2_processed_720.png
# İşlenen görüntüler kaydedildi: 2_processed_721.png
# İşlenen görüntüler kaydedildi: 2_processed_722.png
# İşlenen görüntüler kaydedildi: 2_processed_723.png
# İşlenen görüntüler kaydedildi: 2_processed_724.png
# İşlenen görüntüler kaydedildi: 2_processed_725.png
# İşlenen görüntüler kaydedildi: 2_processed_726.png
# İşlenen görüntüler kaydedildi: 2_processed_727.png
# İşlenen görüntüler kaydedildi: 2_processed_728.png
# İşlenen görüntüler kaydedildi: 2_processed_729.png
# İşlenen görüntüler kaydedildi: 2_processed_73.png
# İşlenen görüntüler kaydedildi: 2_processed_730.png
# İşlenen görüntüler kaydedildi: 2_processed_731.png
# İşlenen görüntüler kaydedildi: 2_processed_732.png
# İşlenen görüntüler kaydedildi: 2_processed_733.png
# İşlenen görüntüler kaydedildi: 2_processed_734.png
# İşlenen görüntüler kaydedildi: 2_processed_735.png
# İşlenen görüntüler kaydedildi: 2_processed_736.png
# İşlenen görüntüler kaydedildi: 2_processed_737.png
# İşlenen görüntüler kaydedildi: 2_processed_738.png
# İşlenen görüntüler kaydedildi: 2_processed_739.png
# İşlenen görüntüler kaydedildi: 2_processed_74.png
# İşlenen görüntüler kaydedildi: 2_processed_740.png
# İşlenen görüntüler kaydedildi: 2_processed_741.png
# İşlenen görüntüler kaydedildi: 2_processed_742.png
# İşlenen görüntüler kaydedildi: 2_processed_743.png
# İşlenen görüntüler kaydedildi: 2_processed_744.png
# İşlenen görüntüler kaydedildi: 2_processed_745.png
# İşlenen görüntüler kaydedildi: 2_processed_746.png
# İşlenen görüntüler kaydedildi: 2_processed_747.png
# İşlenen görüntüler kaydedildi: 2_processed_748.png
# İşlenen görüntüler kaydedildi: 2_processed_749.png
# İşlenen görüntüler kaydedildi: 2_processed_75.png
# İşlenen görüntüler kaydedildi: 2_processed_750.png
# İşlenen görüntüler kaydedildi: 2_processed_751.png
# İşlenen görüntüler kaydedildi: 2_processed_752.png
# İşlenen görüntüler kaydedildi: 2_processed_753.png
# İşlenen görüntüler kaydedildi: 2_processed_754.png
# İşlenen görüntüler kaydedildi: 2_processed_755.png
# İşlenen görüntüler kaydedildi: 2_processed_756.png
# İşlenen görüntüler kaydedildi: 2_processed_757.png
# İşlenen görüntüler kaydedildi: 2_processed_758.png
# İşlenen görüntüler kaydedildi: 2_processed_759.png
# İşlenen görüntüler kaydedildi: 2_processed_76.png
# İşlenen görüntüler kaydedildi: 2_processed_760.png
# İşlenen görüntüler kaydedildi: 2_processed_761.png
# İşlenen görüntüler kaydedildi: 2_processed_762.png
# İşlenen görüntüler kaydedildi: 2_processed_763.png
# İşlenen görüntüler kaydedildi: 2_processed_764.png
# İşlenen görüntüler kaydedildi: 2_processed_765.png
# İşlenen görüntüler kaydedildi: 2_processed_766.png
# İşlenen görüntüler kaydedildi: 2_processed_767.png
# İşlenen görüntüler kaydedildi: 2_processed_768.png
# İşlenen görüntüler kaydedildi: 2_processed_769.png
# İşlenen görüntüler kaydedildi: 2_processed_77.png
# İşlenen görüntüler kaydedildi: 2_processed_770.png
# İşlenen görüntüler kaydedildi: 2_processed_771.png
# İşlenen görüntüler kaydedildi: 2_processed_772.png
# İşlenen görüntüler kaydedildi: 2_processed_773.png
# İşlenen görüntüler kaydedildi: 2_processed_774.png
# İşlenen görüntüler kaydedildi: 2_processed_775.png
# İşlenen görüntüler kaydedildi: 2_processed_776.png
# İşlenen görüntüler kaydedildi: 2_processed_777.png
# İşlenen görüntüler kaydedildi: 2_processed_778.png
# İşlenen görüntüler kaydedildi: 2_processed_779.png
# İşlenen görüntüler kaydedildi: 2_processed_78.png
# İşlenen görüntüler kaydedildi: 2_processed_780.png
# İşlenen görüntüler kaydedildi: 2_processed_781.png
# İşlenen görüntüler kaydedildi: 2_processed_782.png
# İşlenen görüntüler kaydedildi: 2_processed_783.png
# İşlenen görüntüler kaydedildi: 2_processed_784.png
# İşlenen görüntüler kaydedildi: 2_processed_785.png
# İşlenen görüntüler kaydedildi: 2_processed_786.png
# İşlenen görüntüler kaydedildi: 2_processed_787.png
# İşlenen görüntüler kaydedildi: 2_processed_788.png
# İşlenen görüntüler kaydedildi: 2_processed_789.png
# İşlenen görüntüler kaydedildi: 2_processed_79.png
# İşlenen görüntüler kaydedildi: 2_processed_790.png
# İşlenen görüntüler kaydedildi: 2_processed_791.png
# İşlenen görüntüler kaydedildi: 2_processed_792.png
# İşlenen görüntüler kaydedildi: 2_processed_793.png
# İşlenen görüntüler kaydedildi: 2_processed_794.png
# İşlenen görüntüler kaydedildi: 2_processed_795.png
# İşlenen görüntüler kaydedildi: 2_processed_796.png
# İşlenen görüntüler kaydedildi: 2_processed_797.png
# İşlenen görüntüler kaydedildi: 2_processed_798.png
# İşlenen görüntüler kaydedildi: 2_processed_799.png
# İşlenen görüntüler kaydedildi: 2_processed_8.png
# İşlenen görüntüler kaydedildi: 2_processed_80.png
# İşlenen görüntüler kaydedildi: 2_processed_800.png
# İşlenen görüntüler kaydedildi: 2_processed_801.png
# İşlenen görüntüler kaydedildi: 2_processed_802.png
# İşlenen görüntüler kaydedildi: 2_processed_803.png
# İşlenen görüntüler kaydedildi: 2_processed_804.png
# İşlenen görüntüler kaydedildi: 2_processed_805.png
# İşlenen görüntüler kaydedildi: 2_processed_806.png
# İşlenen görüntüler kaydedildi: 2_processed_807.png
# İşlenen görüntüler kaydedildi: 2_processed_808.png
# İşlenen görüntüler kaydedildi: 2_processed_809.png
# İşlenen görüntüler kaydedildi: 2_processed_81.png
# İşlenen görüntüler kaydedildi: 2_processed_810.png
# İşlenen görüntüler kaydedildi: 2_processed_811.png
# İşlenen görüntüler kaydedildi: 2_processed_812.png
# İşlenen görüntüler kaydedildi: 2_processed_813.png
# İşlenen görüntüler kaydedildi: 2_processed_814.png
# İşlenen görüntüler kaydedildi: 2_processed_815.png
# İşlenen görüntüler kaydedildi: 2_processed_816.png
# İşlenen görüntüler kaydedildi: 2_processed_817.png
# İşlenen görüntüler kaydedildi: 2_processed_818.png
# İşlenen görüntüler kaydedildi: 2_processed_819.png
# İşlenen görüntüler kaydedildi: 2_processed_82.png
# İşlenen görüntüler kaydedildi: 2_processed_820.png
# İşlenen görüntüler kaydedildi: 2_processed_821.png
# İşlenen görüntüler kaydedildi: 2_processed_822.png
# İşlenen görüntüler kaydedildi: 2_processed_823.png
# İşlenen görüntüler kaydedildi: 2_processed_824.png
# İşlenen görüntüler kaydedildi: 2_processed_825.png
# İşlenen görüntüler kaydedildi: 2_processed_826.png
# İşlenen görüntüler kaydedildi: 2_processed_827.png
# İşlenen görüntüler kaydedildi: 2_processed_828.png
# İşlenen görüntüler kaydedildi: 2_processed_829.png
# İşlenen görüntüler kaydedildi: 2_processed_83.png
# İşlenen görüntüler kaydedildi: 2_processed_830.png
# İşlenen görüntüler kaydedildi: 2_processed_831.png
# İşlenen görüntüler kaydedildi: 2_processed_832.png
# İşlenen görüntüler kaydedildi: 2_processed_833.png
# İşlenen görüntüler kaydedildi: 2_processed_834.png
# İşlenen görüntüler kaydedildi: 2_processed_835.png
# İşlenen görüntüler kaydedildi: 2_processed_836.png
# İşlenen görüntüler kaydedildi: 2_processed_837.png
# İşlenen görüntüler kaydedildi: 2_processed_838.png
# İşlenen görüntüler kaydedildi: 2_processed_839.png
# İşlenen görüntüler kaydedildi: 2_processed_84.png
# İşlenen görüntüler kaydedildi: 2_processed_840.png
# İşlenen görüntüler kaydedildi: 2_processed_841.png
# İşlenen görüntüler kaydedildi: 2_processed_842.png
# İşlenen görüntüler kaydedildi: 2_processed_843.png
# İşlenen görüntüler kaydedildi: 2_processed_844.png
# İşlenen görüntüler kaydedildi: 2_processed_845.png
# İşlenen görüntüler kaydedildi: 2_processed_846.png
# İşlenen görüntüler kaydedildi: 2_processed_847.png
# İşlenen görüntüler kaydedildi: 2_processed_848.png
# İşlenen görüntüler kaydedildi: 2_processed_849.png
# İşlenen görüntüler kaydedildi: 2_processed_85.png
# İşlenen görüntüler kaydedildi: 2_processed_850.png
# İşlenen görüntüler kaydedildi: 2_processed_851.png
# İşlenen görüntüler kaydedildi: 2_processed_852.png
# İşlenen görüntüler kaydedildi: 2_processed_853.png
# İşlenen görüntüler kaydedildi: 2_processed_854.png
# İşlenen görüntüler kaydedildi: 2_processed_855.png
# İşlenen görüntüler kaydedildi: 2_processed_856.png
# İşlenen görüntüler kaydedildi: 2_processed_857.png
# İşlenen görüntüler kaydedildi: 2_processed_858.png
# İşlenen görüntüler kaydedildi: 2_processed_859.png
# İşlenen görüntüler kaydedildi: 2_processed_86.png
# İşlenen görüntüler kaydedildi: 2_processed_860.png
# İşlenen görüntüler kaydedildi: 2_processed_861.png
# İşlenen görüntüler kaydedildi: 2_processed_862.png
# İşlenen görüntüler kaydedildi: 2_processed_863.png
# İşlenen görüntüler kaydedildi: 2_processed_864.png
# İşlenen görüntüler kaydedildi: 2_processed_865.png
# İşlenen görüntüler kaydedildi: 2_processed_866.png
# İşlenen görüntüler kaydedildi: 2_processed_867.png
# İşlenen görüntüler kaydedildi: 2_processed_868.png
# İşlenen görüntüler kaydedildi: 2_processed_869.png
# İşlenen görüntüler kaydedildi: 2_processed_87.png
# İşlenen görüntüler kaydedildi: 2_processed_870.png
# İşlenen görüntüler kaydedildi: 2_processed_871.png
# İşlenen görüntüler kaydedildi: 2_processed_872.png
# İşlenen görüntüler kaydedildi: 2_processed_873.png
# İşlenen görüntüler kaydedildi: 2_processed_874.png
# İşlenen görüntüler kaydedildi: 2_processed_875.png
# İşlenen görüntüler kaydedildi: 2_processed_876.png
# İşlenen görüntüler kaydedildi: 2_processed_877.png
# İşlenen görüntüler kaydedildi: 2_processed_878.png
# İşlenen görüntüler kaydedildi: 2_processed_879.png
# İşlenen görüntüler kaydedildi: 2_processed_88.png
# İşlenen görüntüler kaydedildi: 2_processed_880.png
# İşlenen görüntüler kaydedildi: 2_processed_881.png
# İşlenen görüntüler kaydedildi: 2_processed_882.png
# İşlenen görüntüler kaydedildi: 2_processed_883.png
# İşlenen görüntüler kaydedildi: 2_processed_884.png
# İşlenen görüntüler kaydedildi: 2_processed_885.png
# İşlenen görüntüler kaydedildi: 2_processed_886.png
# İşlenen görüntüler kaydedildi: 2_processed_887.png
# İşlenen görüntüler kaydedildi: 2_processed_888.png
# İşlenen görüntüler kaydedildi: 2_processed_889.png
# İşlenen görüntüler kaydedildi: 2_processed_89.png
# İşlenen görüntüler kaydedildi: 2_processed_890.png
# İşlenen görüntüler kaydedildi: 2_processed_891.png
# İşlenen görüntüler kaydedildi: 2_processed_892.png
# İşlenen görüntüler kaydedildi: 2_processed_893.png
# İşlenen görüntüler kaydedildi: 2_processed_894.png
# İşlenen görüntüler kaydedildi: 2_processed_895.png
# İşlenen görüntüler kaydedildi: 2_processed_896.png
# İşlenen görüntüler kaydedildi: 2_processed_897.png
# İşlenen görüntüler kaydedildi: 2_processed_898.png
# İşlenen görüntüler kaydedildi: 2_processed_899.png
# İşlenen görüntüler kaydedildi: 2_processed_9.png
# İşlenen görüntüler kaydedildi: 2_processed_90.png
# İşlenen görüntüler kaydedildi: 2_processed_900.png
# İşlenen görüntüler kaydedildi: 2_processed_901.png
# İşlenen görüntüler kaydedildi: 2_processed_902.png
# İşlenen görüntüler kaydedildi: 2_processed_903.png
# İşlenen görüntüler kaydedildi: 2_processed_904.png
# İşlenen görüntüler kaydedildi: 2_processed_905.png
# İşlenen görüntüler kaydedildi: 2_processed_906.png
# İşlenen görüntüler kaydedildi: 2_processed_907.png
# İşlenen görüntüler kaydedildi: 2_processed_908.png
# İşlenen görüntüler kaydedildi: 2_processed_909.png
# İşlenen görüntüler kaydedildi: 2_processed_91.png
# İşlenen görüntüler kaydedildi: 2_processed_910.png
# İşlenen görüntüler kaydedildi: 2_processed_911.png
# İşlenen görüntüler kaydedildi: 2_processed_912.png
# İşlenen görüntüler kaydedildi: 2_processed_913.png
# İşlenen görüntüler kaydedildi: 2_processed_914.png
# İşlenen görüntüler kaydedildi: 2_processed_915.png
# İşlenen görüntüler kaydedildi: 2_processed_916.png
# İşlenen görüntüler kaydedildi: 2_processed_917.png
# İşlenen görüntüler kaydedildi: 2_processed_918.png
# İşlenen görüntüler kaydedildi: 2_processed_919.png
# İşlenen görüntüler kaydedildi: 2_processed_92.png
# İşlenen görüntüler kaydedildi: 2_processed_920.png
# İşlenen görüntüler kaydedildi: 2_processed_921.png
# İşlenen görüntüler kaydedildi: 2_processed_922.png
# İşlenen görüntüler kaydedildi: 2_processed_923.png
# İşlenen görüntüler kaydedildi: 2_processed_924.png
# İşlenen görüntüler kaydedildi: 2_processed_925.png
# İşlenen görüntüler kaydedildi: 2_processed_926.png
# İşlenen görüntüler kaydedildi: 2_processed_927.png
# İşlenen görüntüler kaydedildi: 2_processed_928.png
# İşlenen görüntüler kaydedildi: 2_processed_929.png
# İşlenen görüntüler kaydedildi: 2_processed_93.png
# İşlenen görüntüler kaydedildi: 2_processed_930.png
# İşlenen görüntüler kaydedildi: 2_processed_931.png
# İşlenen görüntüler kaydedildi: 2_processed_932.png
# İşlenen görüntüler kaydedildi: 2_processed_933.png
# İşlenen görüntüler kaydedildi: 2_processed_934.png
# İşlenen görüntüler kaydedildi: 2_processed_935.png
# İşlenen görüntüler kaydedildi: 2_processed_936.png
# İşlenen görüntüler kaydedildi: 2_processed_937.png
# İşlenen görüntüler kaydedildi: 2_processed_938.png
# İşlenen görüntüler kaydedildi: 2_processed_939.png
# İşlenen görüntüler kaydedildi: 2_processed_94.png
# İşlenen görüntüler kaydedildi: 2_processed_940.png
# İşlenen görüntüler kaydedildi: 2_processed_941.png
# İşlenen görüntüler kaydedildi: 2_processed_942.png
# İşlenen görüntüler kaydedildi: 2_processed_943.png
# İşlenen görüntüler kaydedildi: 2_processed_944.png
# İşlenen görüntüler kaydedildi: 2_processed_945.png
# İşlenen görüntüler kaydedildi: 2_processed_946.png
# İşlenen görüntüler kaydedildi: 2_processed_947.png
# İşlenen görüntüler kaydedildi: 2_processed_948.png
# İşlenen görüntüler kaydedildi: 2_processed_949.png
# İşlenen görüntüler kaydedildi: 2_processed_95.png
# İşlenen görüntüler kaydedildi: 2_processed_950.png
# İşlenen görüntüler kaydedildi: 2_processed_951.png
# İşlenen görüntüler kaydedildi: 2_processed_952.png
# İşlenen görüntüler kaydedildi: 2_processed_953.png
# İşlenen görüntüler kaydedildi: 2_processed_954.png
# İşlenen görüntüler kaydedildi: 2_processed_955.png
# İşlenen görüntüler kaydedildi: 2_processed_956.png
# İşlenen görüntüler kaydedildi: 2_processed_957.png
# İşlenen görüntüler kaydedildi: 2_processed_958.png
# İşlenen görüntüler kaydedildi: 2_processed_959.png
# İşlenen görüntüler kaydedildi: 2_processed_96.png
# İşlenen görüntüler kaydedildi: 2_processed_960.png
# İşlenen görüntüler kaydedildi: 2_processed_961.png
# İşlenen görüntüler kaydedildi: 2_processed_962.png
# İşlenen görüntüler kaydedildi: 2_processed_963.png
# İşlenen görüntüler kaydedildi: 2_processed_964.png
# İşlenen görüntüler kaydedildi: 2_processed_965.png
# İşlenen görüntüler kaydedildi: 2_processed_966.png
# İşlenen görüntüler kaydedildi: 2_processed_967.png
# İşlenen görüntüler kaydedildi: 2_processed_968.png
# İşlenen görüntüler kaydedildi: 2_processed_969.png
# İşlenen görüntüler kaydedildi: 2_processed_97.png
# İşlenen görüntüler kaydedildi: 2_processed_970.png
# İşlenen görüntüler kaydedildi: 2_processed_971.png
# İşlenen görüntüler kaydedildi: 2_processed_972.png
# İşlenen görüntüler kaydedildi: 2_processed_973.png
# İşlenen görüntüler kaydedildi: 2_processed_974.png
# İşlenen görüntüler kaydedildi: 2_processed_975.png
# İşlenen görüntüler kaydedildi: 2_processed_976.png
# İşlenen görüntüler kaydedildi: 2_processed_977.png
# İşlenen görüntüler kaydedildi: 2_processed_978.png
# İşlenen görüntüler kaydedildi: 2_processed_979.png
# İşlenen görüntüler kaydedildi: 2_processed_98.png
# İşlenen görüntüler kaydedildi: 2_processed_980.png
# İşlenen görüntüler kaydedildi: 2_processed_981.png
# İşlenen görüntüler kaydedildi: 2_processed_982.png
# İşlenen görüntüler kaydedildi: 2_processed_983.png
# İşlenen görüntüler kaydedildi: 2_processed_984.png
# İşlenen görüntüler kaydedildi: 2_processed_985.png
# İşlenen görüntüler kaydedildi: 2_processed_986.png
# İşlenen görüntüler kaydedildi: 2_processed_987.png
# İşlenen görüntüler kaydedildi: 2_processed_988.png
# İşlenen görüntüler kaydedildi: 2_processed_989.png
# İşlenen görüntüler kaydedildi: 2_processed_99.png
# İşlenen görüntüler kaydedildi: 2_processed_990.png
# İşlenen görüntüler kaydedildi: 2_processed_991.png
# İşlenen görüntüler kaydedildi: 2_processed_992.png
# İşlenen görüntüler kaydedildi: 2_processed_993.png
# İşlenen görüntüler kaydedildi: 2_processed_994.png
# İşlenen görüntüler kaydedildi: 2_processed_995.png
# İşlenen görüntüler kaydedildi: 2_processed_996.png
# İşlenen görüntüler kaydedildi: 2_processed_997.png
# İşlenen görüntüler kaydedildi: 2_processed_998.png
# İşlenen görüntüler kaydedildi: 2_processed_999.png

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Resimlerin bulunduğu dizin kırpma kodu
input_dir = 'Output_filtered/label_1_2'
output_dir = 'Output_filtered/label_1_2'  # Aynı dizine yazmak için aynı dizini kullanıyoruz

# Dizindeki tüm resim dosyalarını listeleme
image_files = [f for f in os.listdir(input_dir) if os.path.isfile(os.path.join(input_dir, f))]

for image_file in image_files:
    image_path = os.path.join(input_dir, image_file)
    mr_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    # Görüntüyü bulanıklaştırma
    blurred = cv2.GaussianBlur(mr_image, (5, 5), 0)

    # İkili (binary) görüntü oluşturma
    _, binary_image = cv2.threshold(blurred, 30, 255, cv2.THRESH_BINARY)

    # Konturları bulma
    contours, _ = cv2.findContours(binary_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    if contours:
        # En büyük konturu (beyin) bulma
        largest_contour = max(contours, key=cv2.contourArea)

        # En büyük konturun etrafındaki dikdörtgeni bulma
        x, y, w, h = cv2.boundingRect(largest_contour)

        # Beyin bölgesini kırpma
        cropped_image = mr_image[y:y+h, x:x+w]

        # Kırpılmış görüntüyü kaydetme (eski resmin üzerine yazma)
        cv2.imwrite(image_path, cropped_image)

    else:
        print(f"Kontur bulunamadı: {image_file}")
        

print("Tüm resimler başarıyla işlendi ve kaydedildi.")
# Out:
# Kontur bulunamadı: 1_edges_10_augmented_3_augmented_1_augmented_1.png
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 41
#      39     else:
#      40         print(f"Kontur bulunamadı: {image_file}")
# ---> 41         os.remove(image_file)
#      43 print("Tüm resimler başarıyla işlendi ve kaydedildi.")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: '1_edges_10_augmented_3_augmented_1_augmented_1.png'
